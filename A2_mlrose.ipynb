# %%
import time
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import mlrose

import warnings
warnings.filterwarnings("ignore")

# %%
problems = ['OneMax','FourPeaks','Knapsack']
algs = ['SA','RHC','MIMIC','GA']
sa_cooling = ['GeomDecay', 'ArithDecay','ExpDecay']
ga_population = [50, 100, 200, 400]
ga_mutation_prob = [0.0001, 0.01, 0.1, 0.2, 0.5, 0.9]
mimic_population = ga_population
mimic_keep_pct = [0.30,0.50,0.70,0.90]
sizes = [r for r in range(10,65,5)]
experiments = 5

results = []

# %%
for n in sizes:
    for p in problems:
        if p == 'Knapsack':
            fitness = mlrose.Knapsack(
                weights=np.random.uniform(size = n), 
                values=np.arange(1, n+1, 1))
        elif p == 'FourPeaks':
            fitness = mlrose.FourPeaks()
        elif p == 'OneMax':
            fitness = mlrose.OneMax()
        
        problem_fit = mlrose.DiscreteOpt(
            length = n,
            fitness_fn = fitness,
            maximize = True,
            max_val = 2 # binary
        )
        
        for a in algs:
            if a == 'RHC':        
                times, optima, iterations = [], [], []
                for e in range(experiments):
                    start = time.time()
                    best_state, best_fitness, curve = mlrose.random_hill_climb(
                        problem_fit,
                        curve=True)
                    times.append(time.time() - start)
                    optima.append(best_fitness)
                    iterations.append(curve.shape[0])
                        
                results.append({'algorithm': a,
                                'problem': p,
                                'mean_time': np.mean(times),
                                'mean_optimum': np.mean(optima),
                                'mean_iterations': np.mean(iterations),
                                'problem_size': n
                                })
            if a == 'SA':
                for opt in sa_cooling:
                    decay = getattr(mlrose, opt)()
                    times, optima, iterations = [], [], []
                    for e in range(experiments):
                        start = time.time()
                        
                        best_state, best_fitness, curve = mlrose.simulated_annealing(
                            problem_fit,
                            schedule=decay,
                            curve=True)
                        times.append(time.time() - start)
                        optima.append(best_fitness)
                        iterations.append(curve.shape[0])
                        
                    results.append({'algorithm': a,
                                    'problem': p,
                                    'mean_time': np.mean(times),
                                    'mean_optimum': np.mean(optima),
                                    'mean_iterations': np.mean(iterations),
                                    'problem_size': n,
                                    'cooling_schedule': opt,
                                   })

            if a == 'GA':
                for pop in ga_population:
                    for prob in ga_mutation_prob:
                        decay = getattr(mlrose, opt)()
                        times, optima, iterations = [], [], []
                        for e in range(experiments):
                            start = time.time()
                        
                            best_state, best_fitness, curve = mlrose.genetic_alg(
                                problem_fit,
                                pop_size = pop,
                                mutation_prob = prob,
                                curve = True
                                )
                            times.append(time.time() - start)
                            optima.append(best_fitness)
                            iterations.append(curve.shape[0])
                        
                        results.append({'algorithm': a,
                                        'problem': p,
                                        'mean_time': np.mean(times),
                                        'mean_optimum': np.mean(optima),
                                        'mean_iterations': np.mean(iterations),
                                        'problem_size': n,
                                        'population': pop,
                                        'mutation_prob': prob
                                       })

            if a == 'MIMIC':
                for pop in mimic_population:
                    for keep in mimic_keep_pct:
                        decay = getattr(mlrose, opt)()
                        times, optima, iterations = [], [], []
                        for e in range(experiments):
                            start = time.time()
                            best_state, best_fitness, curve = mlrose.mimic(
                                problem_fit,
                                pop_size = pop,
                                keep_pct = keep,
                                fast_mimic = True,
                                curve = True
                            )
                            times.append(time.time() - start)
                            optima.append(best_fitness)
                            iterations.append(curve.shape[0])
                        
                        results.append({'algorithm': a,
                                        'problem': p,
                                        'mean_time': np.mean(times),
                                        'mean_optimum': np.mean(optima),
                                        'mean_iterations': np.mean(iterations),
                                        'problem_size': n,
                                        'population': pop,
                                        'samples_kept': keep
                                       })

# %%
results
# Out:
# [{'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.004886341094970703,
#   'mean_optimum': 9.0,
#   'mean_iterations': 106.8,
#   'problem_size': 10,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.038310670852661134,
#   'mean_optimum': 8.2,
#   'mean_iterations': 1276.4,
#   'problem_size': 10,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.004890060424804688,
#   'mean_optimum': 9.6,
#   'mean_iterations': 168.8,
#   'problem_size': 10,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'OneMax',
#   'mean_time': 0.0004901885986328125,
#   'mean_optimum': 9.0,
#   'mean_iterations': 23.8,
#   'problem_size': 10},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.033520984649658206,
#   'mean_optimum': 9.2,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.03774614334106445,
#   'mean_optimum': 9.6,
#   'mean_iterations': 12.2,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.04025425910949707,
#   'mean_optimum': 9.2,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.0505434513092041,
#   'mean_optimum': 9.0,
#   'mean_iterations': 15.8,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.0367548942565918,
#   'mean_optimum': 9.6,
#   'mean_iterations': 10.8,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.04387941360473633,
#   'mean_optimum': 9.8,
#   'mean_iterations': 11.6,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.04661722183227539,
#   'mean_optimum': 9.4,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.049441289901733396,
#   'mean_optimum': 9.0,
#   'mean_iterations': 11.4,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.056349754333496094,
#   'mean_optimum': 9.8,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.05689768791198731,
#   'mean_optimum': 9.6,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06127176284790039,
#   'mean_optimum': 9.8,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.055361032485961914,
#   'mean_optimum': 9.6,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.062360954284667966,
#   'mean_optimum': 9.6,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06828570365905762,
#   'mean_optimum': 9.8,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.0663074016571045,
#   'mean_optimum': 10.0,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06497740745544434,
#   'mean_optimum': 9.2,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.04928956031799316,
#   'mean_optimum': 10.0,
#   'mean_iterations': 15.6,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.05568561553955078,
#   'mean_optimum': 10.0,
#   'mean_iterations': 17.2,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.05261750221252441,
#   'mean_optimum': 10.0,
#   'mean_iterations': 15.8,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.05065951347351074,
#   'mean_optimum': 9.6,
#   'mean_iterations': 14.8,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.04963936805725098,
#   'mean_optimum': 9.4,
#   'mean_iterations': 13.6,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.051389217376708984,
#   'mean_optimum': 9.0,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.09324555397033692,
#   'mean_optimum': 10.0,
#   'mean_iterations': 14.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.08838915824890137,
#   'mean_optimum': 10.0,
#   'mean_iterations': 13.8,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.08849511146545411,
#   'mean_optimum': 10.0,
#   'mean_iterations': 13.4,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.09955143928527832,
#   'mean_optimum': 10.0,
#   'mean_iterations': 14.4,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.12376585006713867,
#   'mean_optimum': 9.8,
#   'mean_iterations': 16.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.11238789558410645,
#   'mean_optimum': 9.4,
#   'mean_iterations': 14.0,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.1940704345703125,
#   'mean_optimum': 10.0,
#   'mean_iterations': 12.6,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.17478785514831544,
#   'mean_optimum': 10.0,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.17722392082214355,
#   'mean_optimum': 10.0,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.2072056293487549,
#   'mean_optimum': 10.0,
#   'mean_iterations': 15.4,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.20801234245300293,
#   'mean_optimum': 9.8,
#   'mean_iterations': 14.2,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.23039817810058594,
#   'mean_optimum': 9.6,
#   'mean_iterations': 14.8,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.29895544052124023,
#   'mean_optimum': 10.0,
#   'mean_iterations': 11.4,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.2866556644439697,
#   'mean_optimum': 10.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.33745555877685546,
#   'mean_optimum': 10.0,
#   'mean_iterations': 12.6,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.3234727382659912,
#   'mean_optimum': 10.0,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.4122489929199219,
#   'mean_optimum': 9.8,
#   'mean_iterations': 14.2,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.4314257621765137,
#   'mean_optimum': 10.0,
#   'mean_iterations': 13.6,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0010006427764892578,
#   'mean_optimum': 17.6,
#   'mean_iterations': 44.8,
#   'problem_size': 10,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.001619577407836914,
#   'mean_optimum': 17.6,
#   'mean_iterations': 74.4,
#   'problem_size': 10,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0011163711547851562,
#   'mean_optimum': 17.2,
#   'mean_iterations': 44.6,
#   'problem_size': 10,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.00017080307006835937,
#   'mean_optimum': 1.2,
#   'mean_iterations': 10.0,
#   'problem_size': 10},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.036017990112304686,
#   'mean_optimum': 15.6,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.03834514617919922,
#   'mean_optimum': 16.8,
#   'mean_iterations': 12.6,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.040644359588623044,
#   'mean_optimum': 17.2,
#   'mean_iterations': 13.4,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04374880790710449,
#   'mean_optimum': 15.0,
#   'mean_iterations': 13.8,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.039441823959350586,
#   'mean_optimum': 17.2,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04143733978271484,
#   'mean_optimum': 17.8,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.041526412963867186,
#   'mean_optimum': 15.4,
#   'mean_iterations': 12.2,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04546093940734863,
#   'mean_optimum': 16.0,
#   'mean_iterations': 13.2,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04748997688293457,
#   'mean_optimum': 17.8,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.049941062927246094,
#   'mean_optimum': 15.4,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04991273880004883,
#   'mean_optimum': 17.8,
#   'mean_iterations': 11.6,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0487419605255127,
#   'mean_optimum': 15.6,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06755585670471191,
#   'mean_optimum': 17.6,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06383519172668457,
#   'mean_optimum': 16.4,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06151318550109863,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.060497188568115236,
#   'mean_optimum': 14.8,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04130878448486328,
#   'mean_optimum': 18.0,
#   'mean_iterations': 13.8,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.038723421096801755,
#   'mean_optimum': 18.0,
#   'mean_iterations': 12.6,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.03725333213806152,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04110260009765625,
#   'mean_optimum': 18.0,
#   'mean_iterations': 12.8,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.047697019577026364,
#   'mean_optimum': 17.8,
#   'mean_iterations': 14.0,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.07837762832641601,
#   'mean_optimum': 17.2,
#   'mean_iterations': 21.2,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.07015085220336914,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.071728515625,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.07711095809936523,
#   'mean_optimum': 18.0,
#   'mean_iterations': 12.2,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.07452125549316406,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.09060826301574706,
#   'mean_optimum': 17.6,
#   'mean_iterations': 13.2,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.13186721801757811,
#   'mean_optimum': 18.0,
#   'mean_iterations': 18.0,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.13579559326171875,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.13528075218200683,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.14175200462341309,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.1463226318359375,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.18999342918395995,
#   'mean_optimum': 18.0,
#   'mean_iterations': 13.6,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.22913103103637694,
#   'mean_optimum': 18.0,
#   'mean_iterations': 15.2,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2707089900970459,
#   'mean_optimum': 18.0,
#   'mean_iterations': 10.8,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2835726261138916,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2843004703521729,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2904493808746338,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3225205421447754,
#   'mean_optimum': 18.0,
#   'mean_iterations': 11.4,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3766523838043213,
#   'mean_optimum': 18.0,
#   'mean_iterations': 12.4,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0011254310607910155,
#   'mean_optimum': 23.2,
#   'mean_iterations': 18.2,
#   'problem_size': 10,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0008700847625732422,
#   'mean_optimum': 23.8,
#   'mean_iterations': 19.2,
#   'problem_size': 10,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0009128093719482422,
#   'mean_optimum': 20.2,
#   'mean_iterations': 26.0,
#   'problem_size': 10,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'Knapsack',
#   'mean_time': 0.00037746429443359376,
#   'mean_optimum': 16.0,
#   'mean_iterations': 13.2,
#   'problem_size': 10},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.05162744522094727,
#   'mean_optimum': 29.4,
#   'mean_iterations': 15.8,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.05134744644165039,
#   'mean_optimum': 30.8,
#   'mean_iterations': 15.0,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06243047714233398,
#   'mean_optimum': 30.8,
#   'mean_iterations': 18.2,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.05097341537475586,
#   'mean_optimum': 31.2,
#   'mean_iterations': 15.0,
#   'problem_size': 10,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.0665898323059082,
#   'mean_optimum': 33.0,
#   'mean_iterations': 17.0,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06303458213806153,
#   'mean_optimum': 33.0,
#   'mean_iterations': 15.6,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06180729866027832,
#   'mean_optimum': 31.8,
#   'mean_iterations': 15.2,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06571307182312011,
#   'mean_optimum': 31.2,
#   'mean_iterations': 16.2,
#   'problem_size': 10,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.07006664276123047,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.6,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.07663640975952149,
#   'mean_optimum': 33.0,
#   'mean_iterations': 14.4,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06890730857849121,
#   'mean_optimum': 33.0,
#   'mean_iterations': 12.8,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.07368998527526856,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.6,
#   'problem_size': 10,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.09022836685180664,
#   'mean_optimum': 33.0,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.09417428970336914,
#   'mean_optimum': 33.0,
#   'mean_iterations': 11.4,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.10416245460510254,
#   'mean_optimum': 33.0,
#   'mean_iterations': 12.8,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.10652403831481934,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.2,
#   'problem_size': 10,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.04557833671569824,
#   'mean_optimum': 32.4,
#   'mean_iterations': 13.4,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.05333752632141113,
#   'mean_optimum': 31.8,
#   'mean_iterations': 15.4,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0558812141418457,
#   'mean_optimum': 33.0,
#   'mean_iterations': 15.0,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.04700469970703125,
#   'mean_optimum': 32.4,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.04689421653747559,
#   'mean_optimum': 30.2,
#   'mean_iterations': 12.2,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.08083257675170899,
#   'mean_optimum': 31.8,
#   'mean_iterations': 20.0,
#   'problem_size': 10,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.10794620513916016,
#   'mean_optimum': 31.8,
#   'mean_iterations': 15.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.08765416145324707,
#   'mean_optimum': 31.8,
#   'mean_iterations': 12.8,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.09831485748291016,
#   'mean_optimum': 33.0,
#   'mean_iterations': 14.0,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.11735739707946777,
#   'mean_optimum': 32.4,
#   'mean_iterations': 16.6,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.11264257431030274,
#   'mean_optimum': 31.8,
#   'mean_iterations': 15.0,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.11295790672302246,
#   'mean_optimum': 30.6,
#   'mean_iterations': 14.0,
#   'problem_size': 10,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.1727449893951416,
#   'mean_optimum': 33.0,
#   'mean_iterations': 12.4,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.1971754550933838,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.8,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.21214962005615234,
#   'mean_optimum': 33.0,
#   'mean_iterations': 14.4,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.19629526138305664,
#   'mean_optimum': 33.0,
#   'mean_iterations': 12.6,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.19237403869628905,
#   'mean_optimum': 31.8,
#   'mean_iterations': 11.4,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.30223283767700193,
#   'mean_optimum': 30.6,
#   'mean_iterations': 17.6,
#   'problem_size': 10,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.37970991134643556,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.3954755783081055,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.8,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.35251965522766116,
#   'mean_optimum': 33.0,
#   'mean_iterations': 11.8,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.34976911544799805,
#   'mean_optimum': 33.0,
#   'mean_iterations': 11.2,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.41326022148132324,
#   'mean_optimum': 33.0,
#   'mean_iterations': 13.0,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 0.6901811122894287,
#   'mean_optimum': 30.8,
#   'mean_iterations': 20.6,
#   'problem_size': 10,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.0026402950286865236,
#   'mean_optimum': 14.4,
#   'mean_iterations': 94.4,
#   'problem_size': 15,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.028106212615966797,
#   'mean_optimum': 12.6,
#   'mean_iterations': 978.0,
#   'problem_size': 15,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.004305028915405273,
#   'mean_optimum': 14.0,
#   'mean_iterations': 146.4,
#   'problem_size': 15,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'OneMax',
#   'mean_time': 0.0004479408264160156,
#   'mean_optimum': 12.0,
#   'mean_iterations': 19.2,
#   'problem_size': 15},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.04935474395751953,
#   'mean_optimum': 14.8,
#   'mean_iterations': 12.6,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06923584938049317,
#   'mean_optimum': 14.2,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.07812733650207519,
#   'mean_optimum': 14.2,
#   'mean_iterations': 15.0,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06871538162231446,
#   'mean_optimum': 13.6,
#   'mean_iterations': 16.4,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.0514488697052002,
#   'mean_optimum': 14.6,
#   'mean_iterations': 11.8,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.06982488632202148,
#   'mean_optimum': 14.8,
#   'mean_iterations': 13.2,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.07506856918334961,
#   'mean_optimum': 14.0,
#   'mean_iterations': 13.2,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.0876162052154541,
#   'mean_optimum': 14.0,
#   'mean_iterations': 19.0,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.09191498756408692,
#   'mean_optimum': 14.8,
#   'mean_iterations': 12.4,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.10762691497802734,
#   'mean_optimum': 14.4,
#   'mean_iterations': 12.2,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.10524439811706543,
#   'mean_optimum': 14.6,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.10700836181640624,
#   'mean_optimum': 13.8,
#   'mean_iterations': 14.4,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.10361590385437011,
#   'mean_optimum': 14.8,
#   'mean_iterations': 11.8,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.10619077682495118,
#   'mean_optimum': 14.8,
#   'mean_iterations': 12.4,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.1118502140045166,
#   'mean_optimum': 14.4,
#   'mean_iterations': 13.4,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.11192293167114258,
#   'mean_optimum': 14.0,
#   'mean_iterations': 13.0,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.05001134872436523,
#   'mean_optimum': 14.0,
#   'mean_iterations': 14.8,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.07375593185424804,
#   'mean_optimum': 14.8,
#   'mean_iterations': 22.0,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.051068878173828124,
#   'mean_optimum': 13.2,
#   'mean_iterations': 14.0,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.052456998825073244,
#   'mean_optimum': 14.0,
#   'mean_iterations': 14.6,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.08233809471130371,
#   'mean_optimum': 13.4,
#   'mean_iterations': 20.0,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.07164387702941895,
#   'mean_optimum': 12.8,
#   'mean_iterations': 14.6,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.1559072494506836,
#   'mean_optimum': 15.0,
#   'mean_iterations': 20.8,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.1239555835723877,
#   'mean_optimum': 15.0,
#   'mean_iterations': 17.0,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.12193827629089356,
#   'mean_optimum': 14.2,
#   'mean_iterations': 16.4,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.11215724945068359,
#   'mean_optimum': 13.6,
#   'mean_iterations': 15.0,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.12270207405090332,
#   'mean_optimum': 13.6,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.138847017288208,
#   'mean_optimum': 13.6,
#   'mean_iterations': 15.2,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.27565641403198243,
#   'mean_optimum': 15.0,
#   'mean_iterations': 20.8,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.2585052490234375,
#   'mean_optimum': 15.0,
#   'mean_iterations': 16.8,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.25608363151550295,
#   'mean_optimum': 14.2,
#   'mean_iterations': 17.8,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.18806085586547852,
#   'mean_optimum': 13.8,
#   'mean_iterations': 13.4,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.24266772270202636,
#   'mean_optimum': 14.0,
#   'mean_iterations': 15.8,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.25388412475585936,
#   'mean_optimum': 14.0,
#   'mean_iterations': 15.2,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.39586830139160156,
#   'mean_optimum': 15.0,
#   'mean_iterations': 15.4,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.40822205543518064,
#   'mean_optimum': 15.0,
#   'mean_iterations': 15.2,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.40241317749023436,
#   'mean_optimum': 14.6,
#   'mean_iterations': 14.4,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.39078536033630373,
#   'mean_optimum': 14.4,
#   'mean_iterations': 13.8,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.44402122497558594,
#   'mean_optimum': 14.2,
#   'mean_iterations': 14.4,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.5570907592773438,
#   'mean_optimum': 14.0,
#   'mean_iterations': 16.2,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0017643451690673828,
#   'mean_optimum': 23.8,
#   'mean_iterations': 78.4,
#   'problem_size': 15,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.002410268783569336,
#   'mean_optimum': 23.6,
#   'mean_iterations': 110.0,
#   'problem_size': 15,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0014188766479492187,
#   'mean_optimum': 26.4,
#   'mean_iterations': 58.0,
#   'problem_size': 15,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.00020532608032226564,
#   'mean_optimum': 2.8,
#   'mean_iterations': 12.2,
#   'problem_size': 15},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.05123858451843262,
#   'mean_optimum': 24.0,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.056516408920288086,
#   'mean_optimum': 23.6,
#   'mean_iterations': 14.8,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.054384374618530275,
#   'mean_optimum': 20.2,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.048582935333251955,
#   'mean_optimum': 18.6,
#   'mean_iterations': 12.0,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.05560503005981445,
#   'mean_optimum': 20.4,
#   'mean_iterations': 12.4,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.054776477813720706,
#   'mean_optimum': 22.8,
#   'mean_iterations': 12.4,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06151823997497559,
#   'mean_optimum': 22.8,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.059353876113891604,
#   'mean_optimum': 22.4,
#   'mean_iterations': 13.2,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06454038619995117,
#   'mean_optimum': 23.8,
#   'mean_iterations': 11.4,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06909613609313965,
#   'mean_optimum': 25.6,
#   'mean_iterations': 12.6,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06754984855651855,
#   'mean_optimum': 25.0,
#   'mean_iterations': 12.4,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06316981315612794,
#   'mean_optimum': 22.2,
#   'mean_iterations': 11.8,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.08607282638549804,
#   'mean_optimum': 24.2,
#   'mean_iterations': 11.4,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.08815913200378418,
#   'mean_optimum': 25.0,
#   'mean_iterations': 12.0,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.09668822288513183,
#   'mean_optimum': 23.4,
#   'mean_iterations': 13.4,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.09351491928100586,
#   'mean_optimum': 24.6,
#   'mean_iterations': 13.0,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.05960779190063477,
#   'mean_optimum': 25.8,
#   'mean_iterations': 18.8,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.04517917633056641,
#   'mean_optimum': 26.2,
#   'mean_iterations': 14.8,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.06529064178466797,
#   'mean_optimum': 26.6,
#   'mean_iterations': 20.8,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.048693370819091794,
#   'mean_optimum': 25.6,
#   'mean_iterations': 15.0,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.0687781810760498,
#   'mean_optimum': 22.8,
#   'mean_iterations': 19.2,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.08134636878967286,
#   'mean_optimum': 22.2,
#   'mean_iterations': 20.0,
#   'problem_size': 15,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.08625054359436035,
#   'mean_optimum': 26.0,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.1041830062866211,
#   'mean_optimum': 27.0,
#   'mean_iterations': 17.2,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.1013514518737793,
#   'mean_optimum': 26.8,
#   'mean_iterations': 16.0,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.12878708839416503,
#   'mean_optimum': 26.2,
#   'mean_iterations': 19.6,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.12017779350280762,
#   'mean_optimum': 24.2,
#   'mean_iterations': 16.8,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.13827133178710938,
#   'mean_optimum': 22.8,
#   'mean_iterations': 17.4,
#   'problem_size': 15,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.1657790184020996,
#   'mean_optimum': 27.0,
#   'mean_iterations': 13.4,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.20318374633789063,
#   'mean_optimum': 27.0,
#   'mean_iterations': 16.4,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.19082202911376953,
#   'mean_optimum': 27.0,
#   'mean_iterations': 14.6,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.29702134132385255,
#   'mean_optimum': 27.0,
#   'mean_iterations': 21.0,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.28319382667541504,
#   'mean_optimum': 24.6,
#   'mean_iterations': 19.2,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.27301297187805174,
#   'mean_optimum': 24.6,
#   'mean_iterations': 15.8,
#   'problem_size': 15,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3493823051452637,
#   'mean_optimum': 27.0,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3759455680847168,
#   'mean_optimum': 27.0,
#   'mean_iterations': 14.0,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.40162010192871095,
#   'mean_optimum': 27.0,
#   'mean_iterations': 14.6,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3785858631134033,
#   'mean_optimum': 27.0,
#   'mean_iterations': 13.8,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.47517919540405273,
#   'mean_optimum': 26.2,
#   'mean_iterations': 16.0,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.4654396057128906,
#   'mean_optimum': 24.0,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0009916305541992187,
#   'mean_optimum': 61.0,
#   'mean_iterations': 29.4,
#   'problem_size': 15,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0013552665710449218,
#   'mean_optimum': 62.2,
#   'mean_iterations': 38.2,
#   'problem_size': 15,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'Knapsack',
#   'mean_time': 0.0008076190948486328,
#   'mean_optimum': 48.4,
#   'mean_iterations': 22.2,
#   'problem_size': 15,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'Knapsack',
#   'mean_time': 0.00028839111328125,
#   'mean_optimum': 24.8,
#   'mean_iterations': 11.2,
#   'problem_size': 15},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.05870323181152344,
#   'mean_optimum': 88.4,
#   'mean_iterations': 15.2,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.07678055763244629,
#   'mean_optimum': 86.0,
#   'mean_iterations': 18.8,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.07852716445922851,
#   'mean_optimum': 81.2,
#   'mean_iterations': 18.2,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06827483177185059,
#   'mean_optimum': 81.8,
#   'mean_iterations': 15.8,
#   'problem_size': 15,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.06217403411865234,
#   'mean_optimum': 89.0,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.10194063186645508,
#   'mean_optimum': 87.4,
#   'mean_iterations': 20.4,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.10351691246032715,
#   'mean_optimum': 83.6,
#   'mean_iterations': 20.6,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.08030238151550292,
#   'mean_optimum': 84.2,
#   'mean_iterations': 15.6,
#   'problem_size': 15,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.08045148849487305,
#   'mean_optimum': 89.0,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.10817298889160157,
#   'mean_optimum': 86.4,
#   'mean_iterations': 16.2,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.13469223976135253,
#   'mean_optimum': 88.2,
#   'mean_iterations': 19.6,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.17682499885559083,
#   'mean_optimum': 86.0,
#   'mean_iterations': 23.4,
#   'problem_size': 15,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.1165956974029541,
#   'mean_optimum': 89.0,
#   'mean_iterations': 13.6,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.1451585292816162,
#   'mean_optimum': 86.0,
#   'mean_iterations': 14.2,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.19227843284606932,
#   'mean_optimum': 86.6,
#   'mean_iterations': 17.8,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'Knapsack',
#   'mean_time': 0.16665868759155272,
#   'mean_optimum': 88.4,
#   'mean_iterations': 16.4,
#   'problem_size': 15,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
# ...
#   'problem_size': 40,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 1.1316522121429444,
#   'mean_optimum': 472.4,
#   'mean_iterations': 19.0,
#   'problem_size': 40,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 1.137122917175293,
#   'mean_optimum': 467.2,
#   'mean_iterations': 18.2,
#   'problem_size': 40,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 1.4396161556243896,
#   'mean_optimum': 457.4,
#   'mean_iterations': 19.6,
#   'problem_size': 40,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'Knapsack',
#   'mean_time': 1.6764702320098877,
#   'mean_optimum': 467.6,
#   'mean_iterations': 18.8,
#   'problem_size': 40,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.004664993286132813,
#   'mean_optimum': 38.8,
#   'mean_iterations': 92.2,
#   'problem_size': 45,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.08195562362670898,
#   'mean_optimum': 37.2,
#   'mean_iterations': 1591.4,
#   'problem_size': 45,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'OneMax',
#   'mean_time': 0.010369157791137696,
#   'mean_optimum': 38.4,
#   'mean_iterations': 171.6,
#   'problem_size': 45,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'OneMax',
#   'mean_time': 0.0017793655395507812,
#   'mean_optimum': 35.2,
#   'mean_iterations': 43.6,
#   'problem_size': 45},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.2972113132476807,
#   'mean_optimum': 44.0,
#   'mean_iterations': 17.8,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.34720258712768554,
#   'mean_optimum': 44.0,
#   'mean_iterations': 20.2,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.4774505615234375,
#   'mean_optimum': 44.2,
#   'mean_iterations': 27.2,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.6045456409454346,
#   'mean_optimum': 38.4,
#   'mean_iterations': 32.6,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.31299633979797364,
#   'mean_optimum': 44.8,
#   'mean_iterations': 16.4,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.3875002384185791,
#   'mean_optimum': 44.6,
#   'mean_iterations': 19.4,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.5295511722564697,
#   'mean_optimum': 44.2,
#   'mean_iterations': 25.6,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.9035079479217529,
#   'mean_optimum': 42.4,
#   'mean_iterations': 43.6,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.3704973220825195,
#   'mean_optimum': 44.4,
#   'mean_iterations': 16.2,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.44261627197265624,
#   'mean_optimum': 44.6,
#   'mean_iterations': 18.6,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.5990025043487549,
#   'mean_optimum': 44.0,
#   'mean_iterations': 23.4,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 1.1509918212890624,
#   'mean_optimum': 42.6,
#   'mean_iterations': 41.8,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.5120687007904052,
#   'mean_optimum': 44.6,
#   'mean_iterations': 15.6,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.6386776924133301,
#   'mean_optimum': 44.4,
#   'mean_iterations': 18.8,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 0.7676613330841064,
#   'mean_optimum': 44.2,
#   'mean_iterations': 21.2,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'OneMax',
#   'mean_time': 1.7002918243408203,
#   'mean_optimum': 44.0,
#   'mean_iterations': 42.4,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.13783254623413085,
#   'mean_optimum': 35.0,
#   'mean_iterations': 24.2,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.15422625541687013,
#   'mean_optimum': 36.0,
#   'mean_iterations': 26.0,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.10722966194152832,
#   'mean_optimum': 34.0,
#   'mean_iterations': 16.6,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.0972513198852539,
#   'mean_optimum': 33.2,
#   'mean_iterations': 13.8,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.13881335258483887,
#   'mean_optimum': 33.0,
#   'mean_iterations': 16.0,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.19781904220581054,
#   'mean_optimum': 32.2,
#   'mean_iterations': 18.0,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.2573307991027832,
#   'mean_optimum': 36.0,
#   'mean_iterations': 22.4,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.29389219284057616,
#   'mean_optimum': 37.4,
#   'mean_iterations': 24.6,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.24112958908081056,
#   'mean_optimum': 34.0,
#   'mean_iterations': 18.6,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.26337175369262694,
#   'mean_optimum': 34.6,
#   'mean_iterations': 19.0,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.2213080883026123,
#   'mean_optimum': 33.8,
#   'mean_iterations': 12.8,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.36711554527282714,
#   'mean_optimum': 32.6,
#   'mean_iterations': 17.0,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.7194519996643066,
#   'mean_optimum': 39.8,
#   'mean_iterations': 31.6,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.5698234558105468,
#   'mean_optimum': 38.4,
#   'mean_iterations': 24.4,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.5333995819091797,
#   'mean_optimum': 35.6,
#   'mean_iterations': 20.6,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.4397470474243164,
#   'mean_optimum': 34.6,
#   'mean_iterations': 15.6,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.6357560157775879,
#   'mean_optimum': 35.0,
#   'mean_iterations': 18.2,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.6258509635925293,
#   'mean_optimum': 34.4,
#   'mean_iterations': 14.2,
#   'problem_size': 45,
#   'population': 200,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 2.117433452606201,
#   'mean_optimum': 42.4,
#   'mean_iterations': 45.4,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 1.428457498550415,
#   'mean_optimum': 39.4,
#   'mean_iterations': 29.8,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 1.0839111804962158,
#   'mean_optimum': 36.0,
#   'mean_iterations': 20.8,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 0.9100788116455079,
#   'mean_optimum': 35.0,
#   'mean_iterations': 16.4,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 1.1371545314788818,
#   'mean_optimum': 34.8,
#   'mean_iterations': 16.6,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'OneMax',
#   'mean_time': 1.359914779663086,
#   'mean_optimum': 34.0,
#   'mean_iterations': 16.0,
#   'problem_size': 45,
#   'population': 400,
#   'mutation_prob': 0.9},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.028865242004394533,
#   'mean_optimum': 55.4,
#   'mean_iterations': 658.4,
#   'problem_size': 45,
#   'cooling_schedule': 'GeomDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.03577919006347656,
#   'mean_optimum': 55.4,
#   'mean_iterations': 792.4,
#   'problem_size': 45,
#   'cooling_schedule': 'ArithDecay'},
#  {'algorithm': 'SA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.026011276245117187,
#   'mean_optimum': 45.2,
#   'mean_iterations': 553.4,
#   'problem_size': 45,
#   'cooling_schedule': 'ExpDecay'},
#  {'algorithm': 'RHC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.00030217170715332033,
#   'mean_optimum': 2.6,
#   'mean_iterations': 10.0,
#   'problem_size': 45},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2821964263916016,
#   'mean_optimum': 40.2,
#   'mean_iterations': 17.6,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2160121440887451,
#   'mean_optimum': 18.2,
#   'mean_iterations': 13.2,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2985866069793701,
#   'mean_optimum': 11.0,
#   'mean_iterations': 17.6,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2453129768371582,
#   'mean_optimum': 11.2,
#   'mean_iterations': 14.4,
#   'problem_size': 45,
#   'population': 50,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3943774223327637,
#   'mean_optimum': 19.8,
#   'mean_iterations': 21.4,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.36376280784606935,
#   'mean_optimum': 21.4,
#   'mean_iterations': 18.4,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2884984970092773,
#   'mean_optimum': 37.4,
#   'mean_iterations': 13.6,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2855343818664551,
#   'mean_optimum': 9.8,
#   'mean_iterations': 13.6,
#   'problem_size': 45,
#   'population': 100,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.43886470794677734,
#   'mean_optimum': 33.0,
#   'mean_iterations': 17.6,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.443070125579834,
#   'mean_optimum': 22.6,
#   'mean_iterations': 17.2,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.37093682289123536,
#   'mean_optimum': 44.4,
#   'mean_iterations': 13.8,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3922447681427002,
#   'mean_optimum': 21.6,
#   'mean_iterations': 14.4,
#   'problem_size': 45,
#   'population': 200,
#   'samples_kept': 0.9},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.9702089309692383,
#   'mean_optimum': 38.2,
#   'mean_iterations': 26.2,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.3},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.5485857486724853,
#   'mean_optimum': 45.0,
#   'mean_iterations': 13.8,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.5},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.5419675827026367,
#   'mean_optimum': 45.8,
#   'mean_iterations': 13.2,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.7},
#  {'algorithm': 'MIMIC',
#   'problem': 'FourPeaks',
#   'mean_time': 0.5994751453399658,
#   'mean_optimum': 19.4,
#   'mean_iterations': 14.2,
#   'problem_size': 45,
#   'population': 400,
#   'samples_kept': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.12440166473388672,
#   'mean_optimum': 36.8,
#   'mean_iterations': 22.0,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.10612473487854004,
#   'mean_optimum': 46.2,
#   'mean_iterations': 18.8,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.14992189407348633,
#   'mean_optimum': 59.8,
#   'mean_iterations': 24.4,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.14303879737854003,
#   'mean_optimum': 55.0,
#   'mean_iterations': 21.2,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.13759231567382812,
#   'mean_optimum': 10.8,
#   'mean_iterations': 16.2,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.21712102890014648,
#   'mean_optimum': 12.4,
#   'mean_iterations': 20.4,
#   'problem_size': 45,
#   'population': 50,
#   'mutation_prob': 0.9},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.17314162254333496,
#   'mean_optimum': 55.8,
#   'mean_iterations': 15.4,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.0001},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.24041199684143066,
#   'mean_optimum': 58.4,
#   'mean_iterations': 20.8,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.01},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2885122776031494,
#   'mean_optimum': 61.0,
#   'mean_iterations': 23.4,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.1},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.25710530281066896,
#   'mean_optimum': 56.8,
#   'mean_iterations': 19.2,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.2},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.2927049160003662,
#   'mean_optimum': 37.4,
#   'mean_iterations': 17.4,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.5},
#  {'algorithm': 'GA',
#   'problem': 'FourPeaks',
#   'mean_time': 0.3825969696044922,
#   'mean_optimum': 29.6,
#   'mean_iterations': 18.2,
#   'problem_size': 45,
#   'population': 100,
#   'mutation_prob': 0.9},
#  ...]

# %%
data = {}
for p in problems:
    for c in sa_cooling:
        metrics = []
        for s in sizes:
            l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == 'SA' and
                 i['cooling_schedule'] == c]
            metrics.append(l[0])
        data[c] = metrics

    figsize = (15,4)
    fig, ax = plt.subplots(figsize=figsize)
    pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
    ax.set_xlabel("Problem size")
    ax.set_ylabel("Mean fitness")
    ax.set_title("Comparing SA cooling decay for {}".format(p))
    fig.savefig("figures/SA_{}_{}_comp.png".format(p, c), bbox_inches='tight')

# %%
data = {}
for p in problems:
    for r in ga_population:
        for m in ga_mutation_prob:
            metrics = []
            for s in sizes:
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == r and
                     i['mutation_prob'] == m]
                metrics.append(l[0])
            data[m] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean fitness")
        ax.set_title("Comparing GA at population {} for {}".format(r, p))
        fig.savefig("figures/GA_{}_pop{}_comp.png".format(p, r),bbox_inches='tight')

# %%
data = {}
for p in problems:
    for r in mimic_population:
        for m in mimic_keep_pct:
            metrics = []
            for s in sizes:
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == r and
                     i['samples_kept'] == m]
                metrics.append(l[0])
            data[m] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean fitness")
        ax.set_title("Comparing MIMIC at population {} for {}".format(r, p))
        fig.savefig("figures/MIMIC_{}_pop{}_comp.png".format(p, r),bbox_inches='tight')

# %%
data = {}
for p in problems:
    metrics = []
    for s in sizes:
        l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
             i['problem'] == p and
             i['algorithm'] == 'RHC']
        metrics.append(l[0])
    data[p] = metrics

figsize = (15,4)
fig, ax = plt.subplots(figsize=figsize)
pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
ax.set_xlabel("Problem size")
ax.set_ylabel("Mean fitness")
ax.set_title("Comparing RHC across all problems")
fig.savefig("figures/RHC_comp.png",bbox_inches='tight')

# %%
#comparing optima for all

cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for p in problems:
    for a in algs:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[p] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean fitness")
        ax.set_title("Comparing the optima for {} for all problems".format(a))
        fig.savefig("figures/all_{}_optima.png".format(a),bbox_inches='tight')

# %%
#comparing times for all
cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for p in problems:
    for a in algs:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[p] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean execution time")
        ax.set_title("Comparing the times for {} for all problems".format(a))
        fig.savefig("figures/all_{}_time.png".format(a),bbox_inches='tight')

# %%
#comparing iterations for all
cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for p in problems:
    for a in algs:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[p] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean iterations")
        ax.set_title("Comparing the iterations for {} for all problems".format(a))
        fig.savefig("figures/all_{}_iterations.png".format(a),bbox_inches='tight')

# %%
#all optima minus knapsack

cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for p in ['OneMax', 'FourPeaks']:
    for a in algs:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[p] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean fitness")
        ax.set_title("Comparing the optima for {} for just OneMax and FourPeaks".format(a))
        fig.savefig("figures/all_nokn_{}_optima.png".format(a),bbox_inches='tight')

# %%
#comparing iterations for all algs
cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for a in algs:
    for p in problems:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_iterations'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[a] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean iterations")
        ax.set_title("Comparing the iterations for {} for all problems".format(p))
        fig.savefig("figures/all_{}_iterations.png".format(p),bbox_inches='tight')

# %%
#comparing times for all algs
cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for a in algs:
    for p in problems:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_time'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[a] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean execution time")
        ax.set_title("Comparing the times for {} for all problems".format(p))
        fig.savefig("figures/all_{}_times.png".format(p),bbox_inches='tight')

# %%
#comparing optima for all algs
cooling = 'GeomDecay'
pop = 200
mut = 0.01
kept = 0.3

data = {}
for a in algs:
    for p in problems:
        metrics = []
        for s in sizes:
            if a == 'RHC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == a]
            elif a == 'SA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                 i['problem'] == p and
                 i['algorithm'] == a and
                 i['cooling_schedule'] == cooling]
            elif a == 'GA':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'GA' and
                     i['population'] == pop and
                     i['mutation_prob'] == mut]
            elif a == 'MIMIC':
                l = [i['mean_optimum'] for i in results if i["problem_size"] == s and
                     i['problem'] == p and
                     i['algorithm'] == 'MIMIC' and
                     i['population'] == pop and
                     i['samples_kept'] == kept]
                
            metrics.append(l[0])
        data[a] = metrics

        figsize = (15,4)
        fig, ax = plt.subplots(figsize=figsize)
        pd.DataFrame(data, index=sizes).plot(marker='o', ax=ax)
        ax.set_xlabel("Problem size")
        ax.set_ylabel("Mean fitness")
        ax.set_title("Comparing the fitness for {} for all problems".format(p))
        fig.savefig("figures/all_{}_optima.png".format(p),bbox_inches='tight')
